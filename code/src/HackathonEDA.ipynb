# %% [markdown]
# <a href="https://colab.research.google.com/github/vchandraiitk/PokerCardGame/blob/master/code/src/HackathonEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading all the data to dataframes
# ### Here we have 5 different data types
#
#
# *   Customer Profile
# *   Orginazation Profile
# *   Social Media Sentiments
# *   Transactions
# *   Different Products in the firm

# %%
import pandas as pd

cust_profile_df = pd.read_csv("https://raw.githubusercontent.com/vchandraiitk/datascience/main/code/src/syntheticdata/CustProfile_Synthetic.csv")
org_profile_df = pd.read_csv("https://raw.githubusercontent.com/vchandraiitk/datascience/main/code/src/syntheticdata/OrgProfile_Synthetic.csv")
sentiments_df = pd.read_csv("https://raw.githubusercontent.com/vchandraiitk/datascience/main/code/src/syntheticdata/Updated_Sentiment_Dataset.csv")
transaction_df = pd.read_csv("https://raw.githubusercontent.com/vchandraiitk/datascience/main/code/src/syntheticdata/Transaction_Synthetic.csv")
product_list_df = pd.read_csv("https://raw.githubusercontent.com/vchandraiitk/datascience/main/code/src/syntheticdata/Wells_Fargo_Product_List.csv")

# %%
cust_profile_df.head(5)
# Out:
#   Customer_Id  Age Gender       Location  Interests      Preferences  \
# 0    CUST2025   24      M        Seattle  Streaming    Subscriptions
# 1    CUST2026   43      M         Austin   Shopping    Subscriptions
# 2    CUST2027   55      M  San Francisco     Gaming      Investments
# 3    CUST2028   41      M  San Francisco     Dining  Digital Banking
# 4    CUST2029   62      M    Los Angeles       Tech    Subscriptions
#
#    Income (per year in dollars) Education       Occupation
# 0                         75076       MBA  Finance Analyst
# 1                        153588       MBA         Engineer
# 2                         83359       PhD         Engineer
# 3                        125659  Graduate       HR Manager
# 4                        107296  Graduate         Engineer

# %%
org_profile_df.head(5)
# Out:
#   Customer_Id     Industry         Financial_Needs       Preferences  \
# 0  ORG_US_000  Real Estate      Payment Processing  Ethical Sourcing
# 1  ORG_US_001      Finance  Supply Chain Financing    Cloud Services
# 2  ORG_US_002  IT Services  Supply Chain Financing  Digital Payments
# 3  ORG_US_003   Healthcare          Business Loans  Digital Payments
# 4  ORG_US_004  IT Services      Payment Processing  Ethical Sourcing
#
#   Revenue (in dollars) No of Employees
# 0            100M-500M       1000-5000
# 1              500M-1B        500-1000
# 2             50M-100M       1000-5000
# 3             50M-100M       1000-5000
# 4              10M-50M       1000-5000

# %%
sentiments_df.head(5)
# Out:
#    Customer_Id  Post_Id  Platform  \
# 0   ORG_US_563     7393  LinkedIn
# 1     CUST2184     1949    Reddit
# 2   ORG_US_251     4530  Facebook
# 3     CUST3403     1018  LinkedIn
# 4  ORG_US_1792     2555    Reddit
#
#                                              Content   Timestamp  \
# 0  Thinking about putting my savings into real es...  27/02/2025
# 1    Saving money is harder than it looks, any tips?  21/07/2024
# 2  Looking at mutual funds for long-term investme...  03/01/2024
# 3  Thinking about putting my savings into real es...  12/07/2024
# 4  Shopping online has become my new favorite thi...  26/02/2024
#
#    Sentiment Score               Intent
# 0         0.193158  Investment Interest
# 1        -0.914086       Budget Concern
# 2         0.748517  Investment Interest
# 3         0.144375  Investment Interest
# 4         0.780828    Shopping Interest

# %%
transaction_df.head(5)
# Out:
#    Customer_Id  Product_Id     Transaction Type                   Category  \
# 0     CUST2899        2445            BNP Usage         Fashion & Clothing
# 1     CUST2175        9230            BNP Usage  Subscription & Promotions
# 2     CUST2757        1580            BNP Usage                Real Estate
# 3  ORG_US_1877        7444  Real Estate Booking         Fashion & Clothing
# 4  ORG_US_1434        1499            BNP Usage                Real Estate
#
#    Amount (in dollars) Purchase Date Payment Mode
# 0               138100    07/03/2025   Debit Card
# 1                83605    02/04/2024   Debit Card
# 2               319628    29/01/2025  Credit Card
# 3               246410    22/08/2024   Debit Card
# 4               226998    14/01/2024   Debit Card

# %%
product_list_df.head(5)
# Out:
#   Product ID          Category        Product Name     Type
# 0     WF1001  Checking Account      Basic Checking    Entry
# 1     WF1002  Checking Account  Preferred Checking   Medium
# 2     WF1003  Checking Account    Premier Checking  Premium
# 3     WF1004   Savings Account    Way2Save Savings    Entry
# 4     WF1005   Savings Account    Platinum Savings  Premium

# %% [markdown]
# ### Displaying Basic Information about datasets

# %%
cust_profile_df.info(), org_profile_df.info(), sentiments_df.info(), transaction_df.info(), product_list_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Customer_Id                   2000 non-null   object
#  1   Age                           2000 non-null   int64
#  2   Gender                        2000 non-null   object
#  3   Location                      2000 non-null   object
#  4   Interests                     2000 non-null   object
#  5   Preferences                   2000 non-null   object
#  6   Income (per year in dollars)  2000 non-null   int64
#  7   Education                     2000 non-null   object
#  8   Occupation                    2000 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 140.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ...

# %% [markdown]
# # Dataset Overview
# ## Based on the initial exploration, here are the key observations:
#
# **Customer Profile (CustProfile_Synthetic.csv)** - Contains 2000 entries with demographic details:
#
# #### Key features: Age, Gender, Location, Interests, Preferences, Income, Education, Occupation.
#
# **Organizational Profile (OrgProfile_Synthetic.csv)** - Contains 2000 entries:
#
# #### Key features: Industry, Financial_Needs, Preferences, Revenue, No of Employees.
#
# **Social Media Sentiments (SMSentiments_Synthetic.csv)** - Contains 8000 entries:
#
# #### Key features: Platform, Content, Timestamp, Sentiment Score, Intent.
#
# **Transaction History (Transaction_Synthetic.csv)** - Contains 8000 transactions:
#
# #### Key features: Product_Id, Transaction Type, Category, Amount, Purchase Date, Payment Mode.
#
# **Wells Fargo Product List (Wells_Fargo_Product_List.csv)** - Contains 37 products:
#
# #### Key features: Product ID, Category, Product Name, Type.

# %% [markdown]
# # Convert Dates to DateTime

# %%
sentiments_df["Timestamp"] = pd.to_datetime(sentiments_df["Timestamp"])
transaction_df["Purchase Date"] = pd.to_datetime(transaction_df["Purchase Date"], format='%d/%m/%Y')
# Out:
# <ipython-input-66-25b0b7133549>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   sentiments_df["Timestamp"] = pd.to_datetime(sentiments_df["Timestamp"])

# %% [markdown]
# # Convert numerical columns to appropriate data types

# %%
cust_profile_df["Income (per year in dollars)"] = cust_profile_df["Income (per year in dollars)"].astype(float)
transaction_df["Amount (in dollars)"] = transaction_df["Amount (in dollars)"].astype(float)

# %%
# Function to extract numeric values from ranges and compute midpoint
def extract_interval_values(interval_str):
    if isinstance(interval_str, str):
        interval_str = interval_str.lower().replace('m', '000000').replace('b', '000000000')  # Convert M and B to full numbers
        parts = interval_str.split('-')
        try:
            lower_bound = float(parts[0].replace(',', '').strip())
            upper_bound = float(parts[1].replace(',', '').strip()) if len(parts) > 1 else lower_bound
            midpoint = (lower_bound + upper_bound) / 2
            return lower_bound, upper_bound, midpoint
        except ValueError:
            return np.nan, np.nan, np.nan  # Return NaN for values that can't be converted
    return np.nan, np.nan, np.nan

# Apply function to extract revenue values
org_profile_df[['Revenue_Lower', 'Revenue_Upper', 'Revenue_Mid']] = org_profile_df['Revenue (in dollars)'].apply(
    lambda x: pd.Series(extract_interval_values(str(x))))

# Apply function to extract No of Employees values
org_profile_df[['Employees_Lower', 'Employees_Upper', 'Employees_Mid']] = org_profile_df['No of Employees'].apply(
    lambda x: pd.Series(extract_interval_values(str(x))))

# Drop original interval columns
org_profile_df.drop(columns=['Revenue (in dollars)', 'No of Employees'], inplace=True)

# %%
org_profile_df.head(5)
# Out:
#   Customer_Id     Industry         Financial_Needs       Preferences  \
# 0  ORG_US_000  Real Estate      Payment Processing  Ethical Sourcing
# 1  ORG_US_001      Finance  Supply Chain Financing    Cloud Services
# 2  ORG_US_002  IT Services  Supply Chain Financing  Digital Payments
# 3  ORG_US_003   Healthcare          Business Loans  Digital Payments
# 4  ORG_US_004  IT Services      Payment Processing  Ethical Sourcing
#
#    Revenue_Lower  Revenue_Upper  Revenue_Mid  Employees_Lower  \
# 0    100000000.0   5.000000e+08  300000000.0           1000.0
# 1    500000000.0   1.000000e+09  750000000.0            500.0
# 2     50000000.0   1.000000e+08   75000000.0           1000.0
# 3     50000000.0   1.000000e+08   75000000.0           1000.0
# 4     10000000.0   5.000000e+07   30000000.0           1000.0
#
#    Employees_Upper  Employees_Mid
# 0           5000.0         3000.0
# 1           1000.0          750.0
# 2           5000.0         3000.0
# 3           5000.0         3000.0
# ...

# %% [markdown]
# # Check Missing Values

# %%
missing_values = {
    "Customer Profile": cust_profile_df.isnull().sum(),
    "Organization Profile": org_profile_df.isnull().sum(),
    "Social Media Sentiments": sentiments_df.isnull().sum(),
    "Transaction History": transaction_df.isnull().sum(),
    "Product List": product_list_df.isnull().sum()
}
missing_values
# Out:
# {'Customer Profile': Customer_Id                     0
#  Age                             0
#  Gender                          0
#  Location                        0
#  Interests                       0
#  Preferences                     0
#  Income (per year in dollars)    0
#  Education                       0
#  Occupation                      0
#  dtype: int64,
#  'Organization Profile': Customer_Id        0
#  Industry           0
#  Financial_Needs    0
#  Preferences        0
#  Revenue_Lower      0
#  Revenue_Upper      0
#  Revenue_Mid        0
#  Employees_Lower    0
#  Employees_Upper    0
#  Employees_Mid      0
#  dtype: int64,
#  'Social Media Sentiments': Customer_Id        0
#  Post_Id            0
#  Platform           0
#  Content            0
#  Timestamp          0
#  Sentiment Score    0
#  Intent             0
#  dtype: int64,
#  'Transaction History': Customer_Id            0
#  Product_Id             0
#  Transaction Type       0
#  Category               0
# ...

# %%
cust_profile_df.head(5)
# Out:
#   Customer_Id  Age Gender       Location  Interests      Preferences  \
# 0    CUST2025   24      M        Seattle  Streaming    Subscriptions
# 1    CUST2026   43      M         Austin   Shopping    Subscriptions
# 2    CUST2027   55      M  San Francisco     Gaming      Investments
# 3    CUST2028   41      M  San Francisco     Dining  Digital Banking
# 4    CUST2029   62      M    Los Angeles       Tech    Subscriptions
#
#    Income (per year in dollars) Education       Occupation
# 0                       75076.0       MBA  Finance Analyst
# 1                      153588.0       MBA         Engineer
# 2                       83359.0       PhD         Engineer
# 3                      125659.0  Graduate       HR Manager
# 4                      107296.0  Graduate         Engineer

# %%
org_profile_df.head(5)
# Out:
#   Customer_Id     Industry         Financial_Needs       Preferences  \
# 0  ORG_US_000  Real Estate      Payment Processing  Ethical Sourcing
# 1  ORG_US_001      Finance  Supply Chain Financing    Cloud Services
# 2  ORG_US_002  IT Services  Supply Chain Financing  Digital Payments
# 3  ORG_US_003   Healthcare          Business Loans  Digital Payments
# 4  ORG_US_004  IT Services      Payment Processing  Ethical Sourcing
#
#    Revenue_Lower  Revenue_Upper  Revenue_Mid  Employees_Lower  \
# 0    100000000.0   5.000000e+08  300000000.0           1000.0
# 1    500000000.0   1.000000e+09  750000000.0            500.0
# 2     50000000.0   1.000000e+08   75000000.0           1000.0
# 3     50000000.0   1.000000e+08   75000000.0           1000.0
# 4     10000000.0   5.000000e+07   30000000.0           1000.0
#
#    Employees_Upper  Employees_Mid
# 0           5000.0         3000.0
# 1           1000.0          750.0
# 2           5000.0         3000.0
# 3           5000.0         3000.0
# ...

# %%
sentiments_df.head(5)
# Out:
#    Customer_Id  Post_Id  Platform  \
# 0   ORG_US_563     7393  LinkedIn
# 1     CUST2184     1949    Reddit
# 2   ORG_US_251     4530  Facebook
# 3     CUST3403     1018  LinkedIn
# 4  ORG_US_1792     2555    Reddit
#
#                                              Content  Timestamp  \
# 0  Thinking about putting my savings into real es... 2025-02-27
# 1    Saving money is harder than it looks, any tips? 2024-07-21
# 2  Looking at mutual funds for long-term investme... 2024-01-03
# 3  Thinking about putting my savings into real es... 2024-07-12
# 4  Shopping online has become my new favorite thi... 2024-02-26
#
#    Sentiment Score               Intent
# 0         0.193158  Investment Interest
# 1        -0.914086       Budget Concern
# 2         0.748517  Investment Interest
# 3         0.144375  Investment Interest
# 4         0.780828    Shopping Interest

# %%
transaction_df.head(5)
# Out:
#    Customer_Id  Product_Id     Transaction Type                   Category  \
# 0     CUST2899        2445            BNP Usage         Fashion & Clothing
# 1     CUST2175        9230            BNP Usage  Subscription & Promotions
# 2     CUST2757        1580            BNP Usage                Real Estate
# 3  ORG_US_1877        7444  Real Estate Booking         Fashion & Clothing
# 4  ORG_US_1434        1499            BNP Usage                Real Estate
#
#    Amount (in dollars) Purchase Date Payment Mode
# 0             138100.0    2025-03-07   Debit Card
# 1              83605.0    2024-04-02   Debit Card
# 2             319628.0    2025-01-29  Credit Card
# 3             246410.0    2024-08-22   Debit Card
# 4             226998.0    2024-01-14   Debit Card

# %%
product_list_df.head(5)
# Out:
#   Product ID          Category        Product Name     Type
# 0     WF1001  Checking Account      Basic Checking    Entry
# 1     WF1002  Checking Account  Preferred Checking   Medium
# 2     WF1003  Checking Account    Premier Checking  Premium
# 3     WF1004   Savings Account    Way2Save Savings    Entry
# 4     WF1005   Savings Account    Platinum Savings  Premium
